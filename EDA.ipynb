# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('CVD Dataset.csv')
df.head(10).T
# Out:
#                                          0                     1  \
# Sex                                      F                     F
# Age                                   32.0                  55.0
# Weight (kg)                           69.1                 118.7
# Height (m)                            1.71                  1.69
# BMI                                   23.6                  41.6
# Abdominal Circumference (cm)          86.2                  82.5
# Blood Pressure (mmHg)               125/79                139/70
# Total Cholesterol (mg/dL)            248.0                 162.0
# HDL (mg/dL)                           78.0                  50.0
# Fasting Blood Sugar (mg/dL)          111.0                 135.0
# Smoking Status                           N                     Y
# Diabetes Status                          Y                     Y
# Physical Activity Level                Low                  High
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1459 entries, 0 to 1528
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Sex                           1459 non-null   object
#  1   Age                           1459 non-null   float64
#  2   Weight (kg)                   1459 non-null   float64
#  3   BMI                           1459 non-null   float64
#  4   Abdominal Circumference (cm)  1459 non-null   float64
#  5   Blood Pressure (mmHg)         1459 non-null   object
#  6   Total Cholesterol (mg/dL)     1459 non-null   float64
#  7   HDL (mg/dL)                   1459 non-null   float64
#  8   Fasting Blood Sugar (mg/dL)   1459 non-null   float64
#  9   Smoking Status                1459 non-null   object
#  10  Diabetes Status               1459 non-null   object
#  11  Physical Activity Level       1459 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (1529, 22)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Diastolic BP                    82
# Weight (kg)                     81
# HDL (mg/dL)                     80
# Waist-to-Height Ratio           79
# Age                             78
# Height (cm)                     74
# Total Cholesterol (mg/dL)       73
# Systolic BP                     71
# CVD Risk Score                  70
# Estimated LDL (mg/dL)           69
# Height (m)                      67
# Abdominal Circumference (cm)    67
# Fasting Blood Sugar (mg/dL)     67
# BMI                             64
# Sex                              0
# Blood Pressure Category          0
# Diabetes Status                  0
# Family History of CVD            0
# Physical Activity Level          0
# Smoking Status                   0
# Blood Pressure (mmHg)            0
# CVD Risk Level                   0
# dtype: int64

# %%
df = df.dropna(subset=['CVD Risk Score'])
df = df.drop(columns=['Height (m)'])

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=df, x='Diastolic BP', bins=30, kde=True)
plt.subplot(1, 2, 2)
sns.boxplot(data=df, x='Diastolic BP')
plt.show()

# %% [markdown]
# It has no Outlier so we can use mean

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=df, x='Weight (kg)', bins=30, kde=True)
plt.subplot(1, 2, 2)
sns.boxplot(data=df, x='Weight (kg)')
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=df, x='HDL (mg/dL)', bins=30, kde=True)
plt.subplot(1, 2, 2)
sns.boxplot(data=df, x='HDL (mg/dL)')
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=df, x='Waist-to-Height Ratio', bins=30, kde=True)
plt.subplot(1, 2, 2)
sns.boxplot(data=df, x='Waist-to-Height Ratio')
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=df, x='Total Cholesterol (mg/dL)', bins=30, kde=True)
plt.subplot(1, 2, 2)
sns.boxplot(data=df, x='Total Cholesterol (mg/dL)')
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=df, x='Height (cm)', bins=30, kde=True)
plt.subplot(1, 2, 2)
sns.boxplot(data=df, x='Height (cm)')
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=df, x='Age', bins=30, kde=True)
plt.subplot(1, 2, 2)
sns.boxplot(data=df, x='Age')
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=df, x='Systolic BP', bins=30, kde=True)
plt.subplot(1, 2, 2)
sns.boxplot(data=df, x='Systolic BP')
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=df, x='CVD Risk Score', bins=30, kde=True)
plt.subplot(1, 2, 2)
sns.boxplot(data=df, x='CVD Risk Score')
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=df, x='Estimated LDL (mg/dL)', bins=30, kde=True)
plt.subplot(1, 2, 2)
sns.boxplot(data=df, x='Estimated LDL (mg/dL)')
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=df, x='BMI', bins=30, kde=True)
plt.subplot(1, 2, 2)
sns.boxplot(data=df, x='BMI')
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=df, x='Abdominal Circumference (cm)', bins=30, kde=True)
plt.subplot(1, 2, 2)
sns.boxplot(data=df, x='Abdominal Circumference (cm)')
plt.show()

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Sex                             0
# Physical Activity Level         0
# CVD Risk Score                  0
# Estimated LDL (mg/dL)           0
# Blood Pressure Category         0
# Diastolic BP                    0
# Systolic BP                     0
# Waist-to-Height Ratio           0
# Height (cm)                     0
# Family History of CVD           0
# Diabetes Status                 0
# Age                             0
# Smoking Status                  0
# Fasting Blood Sugar (mg/dL)     0
# HDL (mg/dL)                     0
# Total Cholesterol (mg/dL)       0
# Blood Pressure (mmHg)           0
# Abdominal Circumference (cm)    0
# BMI                             0
# Weight (kg)                     0
# CVD Risk Level                  0
# dtype: int64

# %%
null_column = ['Weight (kg)','HDL (mg/dL)','Diastolic BP','Waist-to-Height Ratio','Total Cholesterol (mg/dL)','Age','BMI','Systolic BP','Height (cm)','Estimated LDL (mg/dL)','Fasting Blood Sugar (mg/dL)','Abdominal Circumference (cm)']

# %%
from sklearn.impute import SimpleImputer
mean_imputer = SimpleImputer(strategy='mean')
df[null_column] = mean_imputer.fit_transform(df[null_column])

# %%
df.to_csv("EDA_done.csv")
